# %%
Ie = 100
B = Ie / 8π
C = -3/5/exp(2)*B
A = B + C
D = B*exp(-1) + C*exp(1)
function cable(x)
    ifelse(x < -1.0, A*exp(x + 1),
    ifelse(-1.0 < x < 0.0, B*exp(-(x + 1)) + C*exp(x + 1),
    D*exp(-2x)))
end


using Gadfly
x = -2:0.001:2
Gadfly.plot(x = x, y = cable.(x), Geom.line)
# Out:
# WARNING: Method definition cable(Any) in module Main at In[5]:7 overwritten at In[6]:7.
# Plot(...)
