# %%
using Plots
reload("SNN")
# Out:
# ex = :(function integrate!(p::IF,params::IFParameters,t) # none, line 2:
#         @inbounds @simd(for i = 1:p.N # none, line 3:
#                     p.v[i] += (dt * (((p.ge[i] + p.gi[i]) - (p.v[i] - params.El)) + p.I[i])) / params.τm # none, line 4:
#                     p.ge[i] += (dt * -(p.ge[i])) / params.τe # none, line 5:
#                     p.gi[i] += (dt * -(p.gi[i])) / params.τi # none, line 6:
#                     p.fire[i] = p.v[i] > params.Vt # none, line 7:
#                     p.v[i] = ifelse(p.fire[i],params.Vr,p.v[i])
#                 end)
#     end)
# ex = :(function integrate!(p::IZ,params::IZParameters,t) # none, line 2:
#         @inbounds for i = 1:p.N # none, line 3:
#                 p.v[i] += (dt / 2) * (((0.04 * p.v[i] ^ 2 + 5.0 * p.v[i] + 140.0) - p.u[i]) + p.I[i]) # none, line 4:
#                 p.v[i] += (dt / 2) * (((0.04 * p.v[i] ^ 2 + 5.0 * p.v[i] + 140.0) - p.u[i]) + p.I[i]) # none, line 5:
# ...

# %%
@evalat SNN dt = 0.01
I =  1e-5*([1:0.1:1.6;1.6:0.01:1.9;1.9:0.1:3])
SNN.IF_curve(SNN.HH, I; duration=4000)
# Out:
# WARNING: redefining constant dt
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 30.6037,384.952 596.063,384.952 596.063,3.93701 30.6037,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="30" y="3" width="566" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   30.6037,379.237 30.6037,9.65223
#   "/>
# ...
